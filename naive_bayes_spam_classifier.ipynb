# %%
# Mount this repository to drive
from google.colab import drive
import os
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Navigate to Directory where all data science projects are stored
# In this folder the github repository will be cloned as a new folder
# %cd /content/drive/MyDrive/Data_science_projects/Classification/Naive_bayes_spam_classification
# Out:
# /content/drive/MyDrive/Data_science_projects/Classification/Naive_bayes_spam_classification

# %%
username = 'debopriyobhowmick'
git_token = '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'
repository = 'sms_spam_classification'

# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'sms_spam_classification'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 1.32 KiB | 24.00 KiB/s, done.

# %%
# %cd /content/drive/MyDrive/Data_science_projects/Classification/Naive_bayes_spam_classification/sms_spam_classification/
# Out:
# /content/drive/MyDrive/Data_science_projects/Classification/Naive_bayes_spam_classification/sms_spam_classification

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	naive_bayes_spam_classifier.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add -A

# %%
# !git commit -m 'Added Spam Classification Notebook'
# Out:
# [main 30e5fbb] Added Spam Classification Notebook
#  1 file changed, 1 insertion(+)
#  create mode 100644 naive_bayes_spam_classifier.ipynb

# %%
# !git push
# Out:
# remote: Permission to debopriyobhowmick/sms_spam_classification.git denied to debopriyobhowmick.
# fatal: unable to access 'https://github.com/debopriyobhowmick/sms_spam_classification/': The requested URL returned error: 403

# %%
# !git config --global user.name "debopriyobhowmick"
# !git config --global user.email "bhowmick.kushal@gmail.com"
# !git config --global user.password "Holalola007!"
